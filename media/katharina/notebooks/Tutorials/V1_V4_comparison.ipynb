# %%
import os
import numpy as np
import matplotlib.pyplot as plt

from scipy.misc import face
import torch
import torchvision
import torchvision.transforms as transforms
import gc

# %%
img_path1 = "/data/monkey/toliaslab/CSRF19_V1/images/"
images1 = [np.load(img_path1 + i) for i in os.listdir(img_path1) if ".npy" in i ]

sal_path1 = "/data/monkey/toliaslab/CSRF19_V1/images_saliency/"
sal_images1 = [np.load(sal_path1 + i) for i in os.listdir(sal_path1) if ".npy" in i ]


img_path4 = "/data/monkey/toliaslab/CSRF19_V4/images/"
images4 = [np.load(img_path4 + i) for i in os.listdir(img_path4) if ".npy" in i ]

sal_path4 = "/data/monkey/toliaslab/CSRF19_V4/images_saliency/"
sal_images4 = [np.load(sal_path4 + i) for i in os.listdir(sal_path4) if ".npy" in i ]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-06e4bc4cb82b> in <module>
#       3
#       4 sal_path1 = "/data/monkey/toliaslab/CSRF19_V1/images_saliency/"
# ----> 5 sal_images1 = [np.load(sal_path1 + i) for i in os.listdir(sal_path1) if ".npy" in i ]
#       6
#       7
#
# <ipython-input-2-06e4bc4cb82b> in <listcomp>(.0)
#       3
#       4 sal_path1 = "/data/monkey/toliaslab/CSRF19_V1/images_saliency/"
# ----> 5 sal_images1 = [np.load(sal_path1 + i) for i in os.listdir(sal_path1) if ".npy" in i ]
#       6
#       7
#
# /usr/local/lib/python3.8/dist-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     450                 return format.open_memmap(file, mode=mmap_mode)
#     451             else:
# --> 452                 return format.read_array(fid, allow_pickle=allow_pickle,
# ...

# %%
print(sal_images1[1].shape)
print(sal_images4[1].shape)

# %%
fig, axs = plt.subplots(10,8, figsize=(20,20))

j= 0
k = 0
for i in range(0, 10):
    for count in range(0,4):
        axs[i][j].matshow(images1[k], cmap="gray")
        j += 1
        if (j>7):
            j = 0
        axs[i][j].matshow(np.exp(sal_images1[k]))
        j+= 1
        if (j>7):
            j = 0
        axs[i][j].matshow(images4[k], cmap="gray")
        j+= 1
        if (j>7):
            j = 0
        axs[i][j].matshow(np.exp(sal_images4[k]))
        j += 1
        if (j>7):
            j = 0
        k += 1
    #axs.axis("off")
