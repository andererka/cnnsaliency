# %% [markdown]
# ## Cropping of size 20 px on each side:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Without cropping
# pay attention to the text region in the first picture

# %% [markdown]
# ![image.png](attachment:image.png)
